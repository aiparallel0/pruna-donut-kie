# %% [markdown]
# # 01 — Baseline: uncompressed DONUT on SROIE Task-3
#
# **Research question:** What is the global token-F1 of the uncompressed fine-tuned DONUT
# (260.78M parameters) on the canonical 347-image SROIE Task-3 test set, measured with
# the same evaluation harness used in the companion study (aiparallel0/kaggle2)?
# This notebook establishes the reference point against which all compressed configurations
# in notebooks 02–06 are compared.

# %%
from pathlib import Path
import json

from src.eval import load_donut, evaluate_model

# %%
# TODO: load the fine-tuned DONUT checkpoint from checkpoints/ and run evaluation.
# Example:
#   model, processor = load_donut(Path("checkpoints/donut-sroie"))
#   metrics = evaluate_model(model, processor)
raise NotImplementedError(
    "Load checkpoint and run evaluate_model(); "
    "do not hard-code any F1 values."
)

# %%
# TODO: after evaluate_model() returns, persist results.
# out_path = Path("results/per_config/baseline.json")
# out_path.parent.mkdir(parents=True, exist_ok=True)
# with out_path.open("w") as fh:
#     json.dump({"config_name": "baseline", **metrics}, fh, indent=2)
raise NotImplementedError("Persist metrics to results/per_config/baseline.json")
