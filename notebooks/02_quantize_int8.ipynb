# %% [markdown]
# # 02 — Int8 quantization (bitsandbytes row-wise scaling)
#
# **Research question:** How much does bitsandbytes int8 quantization reduce the
# effective parameter footprint of the fine-tuned DONUT, and at what cost in
# global token-F1 on the 347-image SROIE Task-3 test set?
# Specifically: does int8 DONUT cross below the 66.93M-parameter pipeline floor
# while remaining within a statistically tolerable margin of the baseline 82.7% F1?

# %%
from pathlib import Path
import json

from src.eval import load_donut, evaluate_model
from src.compress import int8

# %%
# TODO: apply int8 compression via Pruna and evaluate.
# Example:
#   import pruna
#   model, processor = load_donut(Path("checkpoints/donut-sroie"))
#   smashed = pruna.smash(model, smash_config=int8())
#   metrics = evaluate_model(smashed, processor)
raise NotImplementedError(
    "Apply int8() smash config and run evaluate_model(); "
    "do not hard-code any F1 values."
)

# %%
# TODO: persist results.
# out_path = Path("results/per_config/quantize_int8.json")
# out_path.parent.mkdir(parents=True, exist_ok=True)
# with out_path.open("w") as fh:
#     json.dump({"config_name": "quantize_int8", **metrics}, fh, indent=2)
raise NotImplementedError("Persist metrics to results/per_config/quantize_int8.json")
