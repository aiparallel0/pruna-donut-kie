# %% [markdown]
# # 03 — Int4 quantization (bitsandbytes NF4 + double quantization)
#
# **Research question:** Does bitsandbytes NF4 int4 quantization with double quantization
# offer a meaningfully better parameter-count reduction than int8, and does the additional
# bit-width reduction produce a measurable F1 degradation on the 347-image SROIE Task-3
# test set?
# This notebook compares the int4 operating point against the int8 result from notebook 02
# and the 66.93M-parameter pipeline floor.

# %%
from pathlib import Path
import json

from src.eval import load_donut, evaluate_model
from src.compress import int4

# %%
# TODO: apply int4 NF4 compression via Pruna and evaluate.
# Example:
#   import pruna
#   model, processor = load_donut(Path("checkpoints/donut-sroie"))
#   smashed = pruna.smash(model, smash_config=int4())
#   metrics = evaluate_model(smashed, processor)
raise NotImplementedError(
    "Apply int4() smash config and run evaluate_model(); "
    "do not hard-code any F1 values."
)

# %%
# TODO: persist results.
# out_path = Path("results/per_config/quantize_int4.json")
# out_path.parent.mkdir(parents=True, exist_ok=True)
# with out_path.open("w") as fh:
#     json.dump({"config_name": "quantize_int4", **metrics}, fh, indent=2)
raise NotImplementedError("Persist metrics to results/per_config/quantize_int4.json")
