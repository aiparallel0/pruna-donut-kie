# %% [markdown]
# # 05 — Teacher-student distillation into a half-depth student
#
# **Research question:** Can a half-depth student model (≈130M parameters) distilled from
# the fine-tuned DONUT teacher via KL divergence on decoder logits at τ=2.0 retain a
# meaningful fraction of the teacher's global token-F1 (82.7%) on the 347-image
# SROIE Task-3 test set?
# Specifically: does the distilled student reach F1 comparable to the pipeline's 85.8%
# at a parameter count below the pipeline's 66.93M floor, or does the student land
# between the two reference points?

# %%
from pathlib import Path
import json

from src.eval import load_donut, evaluate_model
from src.compress import distill_half

# %%
# TODO: apply half-depth distillation via Pruna and evaluate.
# Example:
#   import pruna
#   model, processor = load_donut(Path("checkpoints/donut-sroie"))
#   smashed = pruna.smash(model, smash_config=distill_half())
#   metrics = evaluate_model(smashed, processor)
raise NotImplementedError(
    "Apply distill_half() smash config and run evaluate_model(); "
    "do not hard-code any F1 values."
)

# %%
# TODO: persist results.
# out_path = Path("results/per_config/distill_half.json")
# out_path.parent.mkdir(parents=True, exist_ok=True)
# with out_path.open("w") as fh:
#     json.dump({"config_name": "distill_half", **metrics}, fh, indent=2)
raise NotImplementedError("Persist metrics to results/per_config/distill_half.json")
