# %% [markdown]
# # 06 — Combination compression configs
#
# **Research question:** Do combinations of compression operators (int8 + 25% structured
# pruning; distill-to-half + int8) place compressed-DONUT on a more favourable point of
# the F1-vs-parameters Pareto frontier than any single operator applied in isolation?
# This notebook evaluates the two combination configs exposed via Pruna's smash_config
# builders against the single-operator results from notebooks 02–05 on the 347-image
# SROIE Task-3 test set.

# %%
from pathlib import Path
import json

from src.eval import load_donut, evaluate_model
from src.compress import int8_prune25, distill_int8

# %%
# TODO: apply combination configs via Pruna and evaluate both.
# Example:
#   import pruna
#   model_a, processor = load_donut(Path("checkpoints/donut-sroie"))
#   smashed_a = pruna.smash(model_a, smash_config=int8_prune25())
#   metrics_a = evaluate_model(smashed_a, processor)
#
#   model_b, _ = load_donut(Path("checkpoints/donut-sroie"))  # fresh load
#   smashed_b = pruna.smash(model_b, smash_config=distill_int8())
#   metrics_b = evaluate_model(smashed_b, processor)
raise NotImplementedError(
    "Apply int8_prune25() and distill_int8() smash configs and run evaluate_model(); "
    "do not hard-code any F1 values."
)

# %%
# TODO: persist results for both combination configs.
# for config_name, metrics in [("int8_prune25", metrics_a),
#                               ("distill_int8", metrics_b)]:
#     out_path = Path(f"results/per_config/{config_name}.json")
#     out_path.parent.mkdir(parents=True, exist_ok=True)
#     with out_path.open("w") as fh:
#         json.dump({"config_name": config_name, **metrics}, fh, indent=2)
raise NotImplementedError(
    "Persist metrics to results/per_config/int8_prune25.json "
    "and results/per_config/distill_int8.json"
)
